# %% [markdown]
# # Data Driven approach for Poverty Anlysis and Prediction System

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Load Dataset

# %%
train_data = pd.read_csv('train_labels.csv')
test_data = pd.read_csv('test_values.csv')
poverty_data = pd.read_csv('poverty_dataset.csv')

# %% [markdown]
# ## Exploratory Data Analysis

# %%
# Display basic information about the datasets
print("Train dataset information:")
print(train_data.info())

print("\nTest dataset information:")
print(test_data.info())

print("\nPoverty dataset information:")
print(poverty_data.info())

# Summary statistics of the poverty dataset
print("\nSummary statistics of the Poverty dataset:")
print(poverty_data.describe())
# Out:
# Train dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   row_id               12600 non-null  int64
#  1   poverty_probability  12600 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 197.0 KB
# None
#
# Test dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8400 entries, 0 to 8399
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   row_id                                 8400 non-null   int64
#  1   country                                8400 non-null   object
#  2   is_urban                               8400 non-null   bool
#  3   age                                    8400 non-null   float64
#  4   female                                 8400 non-null   bool
#  5   married                                8400 non-null   bool
#  6   religion                               8400 non-null   object
#  7   relationship_to_hh_head                8400 non-null   object
#  8   education_level                        8251 non-null   float64
#  9   literacy                               8400 non-null   bool
#  10  can_add                                8400 non-null   bool
#  11  can_divide                             8400 non-null   bool
#  12  can_calc_percents                      8400 non-null   bool
#  13  can_calc_compounding                   8400 non-null   bool
#  14  employed_last_year                     8400 non-null   bool
#  15  employment_category_last_year          8400 non-null   object
#  16  employment_type_last_year              8400 non-null   object
#  17  share_hh_income_provided               8207 non-null   float64
#  18  income_ag_livestock_last_year          8400 non-null   bool
#  19  income_friends_family_last_year        8400 non-null   bool
#  20  income_government_last_year            8400 non-null   bool
#  21  income_own_business_last_year          8400 non-null   bool
#  22  income_private_sector_last_year        8400 non-null   bool
#  23  income_public_sector_last_year         8400 non-null   bool
#  24  num_times_borrowed_last_year           8400 non-null   int64
#  25  borrowing_recency                      8400 non-null   int64
#  26  formal_savings                         8400 non-null   bool
#  27  informal_savings                       8400 non-null   bool
#  28  cash_property_savings                  8400 non-null   bool
#  29  has_insurance                          8400 non-null   bool
#  30  has_investment                         8400 non-null   bool
#  31  bank_interest_rate                     222 non-null    float64
#  32  mm_interest_rate                       94 non-null     float64
#  33  mfi_interest_rate                      98 non-null     float64
#  34  other_fsp_interest_rate                170 non-null    float64
#  35  num_shocks_last_year                   8400 non-null   int64
#  36  avg_shock_strength_last_year           8400 non-null   float64
#  37  borrowed_for_emergency_last_year       8400 non-null   bool
#  38  borrowed_for_daily_expenses_last_year  8400 non-null   bool
#  39  borrowed_for_home_or_biz_last_year     8400 non-null   bool
#  40  phone_technology                       8400 non-null   int64
#  41  can_call                               8400 non-null   bool
#  42  can_text                               8400 non-null   bool
#  43  can_use_internet                       8400 non-null   bool
#  44  can_make_transaction                   8400 non-null   bool
#  45  phone_ownership                        8400 non-null   int64
#  46  advanced_phone_use                     8400 non-null   bool
#  47  reg_bank_acct                          8400 non-null   bool
#  48  reg_mm_acct                            8400 non-null   bool
#  49  reg_formal_nbfi_account                8400 non-null   bool
#  50  financially_included                   8400 non-null   bool
#  51  active_bank_user                       8400 non-null   bool
#  52  active_mm_user                         8400 non-null   bool
#  53  active_formal_nbfi_user                8400 non-null   bool
#  54  active_informal_nbfi_user              8400 non-null   bool
#  55  nonreg_active_mm_user                  8400 non-null   bool
#  56  num_formal_institutions_last_year      8400 non-null   int64
#  57  num_informal_institutions_last_year    8400 non-null   int64
#  58  num_financial_activities_last_year     8400 non-null   int64
# dtypes: bool(37), float64(8), int64(9), object(5)
# memory usage: 1.7+ MB
# None
#
# Poverty dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 59 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   row_id                                 12600 non-null  int64
#  1   country                                12600 non-null  object
#  2   is_urban                               12600 non-null  bool
#  3   age                                    12600 non-null  float64
#  4   female                                 12600 non-null  bool
#  5   married                                12600 non-null  bool
#  6   religion                               12600 non-null  object
#  7   relationship_to_hh_head                12600 non-null  object
#  8   education_level                        12364 non-null  float64
#  9   literacy                               12600 non-null  bool
#  10  can_add                                12600 non-null  bool
#  11  can_divide                             12600 non-null  bool
#  12  can_calc_percents                      12600 non-null  bool
#  13  can_calc_compounding                   12600 non-null  bool
#  14  employed_last_year                     12600 non-null  bool
#  15  employment_category_last_year          12600 non-null  object
#  16  employment_type_last_year              12600 non-null  object
#  17  share_hh_income_provided               12295 non-null  float64
#  18  income_ag_livestock_last_year          12600 non-null  bool
#  19  income_friends_family_last_year        12600 non-null  bool
#  20  income_government_last_year            12600 non-null  bool
#  21  income_own_business_last_year          12600 non-null  bool
#  22  income_private_sector_last_year        12600 non-null  bool
#  23  income_public_sector_last_year         12600 non-null  bool
#  24  num_times_borrowed_last_year           12600 non-null  int64
#  25  borrowing_recency                      12600 non-null  int64
#  26  formal_savings                         12600 non-null  bool
#  27  informal_savings                       12600 non-null  bool
#  28  cash_property_savings                  12600 non-null  bool
#  29  has_insurance                          12600 non-null  bool
#  30  has_investment                         12600 non-null  bool
#  31  bank_interest_rate                     289 non-null    float64
#  32  mm_interest_rate                       151 non-null    float64
#  33  mfi_interest_rate                      201 non-null    float64
#  34  other_fsp_interest_rate                239 non-null    float64
#  35  num_shocks_last_year                   12600 non-null  int64
#  36  avg_shock_strength_last_year           12600 non-null  float64
#  37  borrowed_for_emergency_last_year       12600 non-null  bool
#  38  borrowed_for_daily_expenses_last_year  12600 non-null  bool
#  39  borrowed_for_home_or_biz_last_year     12600 non-null  bool
#  40  phone_technology                       12600 non-null  int64
#  41  can_call                               12600 non-null  bool
#  42  can_text                               12600 non-null  bool
#  43  can_use_internet                       12600 non-null  bool
#  44  can_make_transaction                   12600 non-null  bool
#  45  phone_ownership                        12600 non-null  int64
#  46  advanced_phone_use                     12600 non-null  bool
#  47  reg_bank_acct                          12600 non-null  bool
#  48  reg_mm_acct                            12600 non-null  bool
#  49  reg_formal_nbfi_account                12600 non-null  bool
#  50  financially_included                   12600 non-null  bool
#  51  active_bank_user                       12600 non-null  bool
#  52  active_mm_user                         12600 non-null  bool
#  53  active_formal_nbfi_user                12600 non-null  bool
#  54  active_informal_nbfi_user              12600 non-null  bool
#  55  nonreg_active_mm_user                  12600 non-null  bool
#  56  num_formal_institutions_last_year      12600 non-null  int64
#  57  num_informal_institutions_last_year    12600 non-null  int64
#  58  num_financial_activities_last_year     12600 non-null  int64
# dtypes: bool(37), float64(8), int64(9), object(5)
# memory usage: 2.6+ MB
# None
#
# Summary statistics of the Poverty dataset:
#              row_id           age  education_level  share_hh_income_provided  \
# count  12600.000000  12600.000000     12364.000000              12295.000000
# mean    6299.500000     36.280714         1.316241                  2.888166
# std     3637.451031     15.145945         0.905442                  1.564284
# min        0.000000     15.000000         0.000000                  1.000000
# 25%     3149.750000     25.000000         1.000000                  1.000000
# 50%     6299.500000     33.000000         1.000000                  2.000000
# 75%     9449.250000     45.000000         2.000000                  5.000000
# max    12599.000000    115.000000         3.000000                  5.000000
#
#        num_times_borrowed_last_year  borrowing_recency  bank_interest_rate  \
# count                  12600.000000       12600.000000          289.000000
# mean                       0.657698           0.866429            9.843080
# std                        0.924598           0.960866           15.033089
# min                        0.000000           0.000000            0.000000
# 25%                        0.000000           0.000000            1.000000
# 50%                        0.000000           0.000000            7.000000
# 75%                        1.000000           2.000000           14.000000
# max                        3.000000           2.000000          100.000000
#
#        mm_interest_rate  mfi_interest_rate  other_fsp_interest_rate  \
# count        151.000000         201.000000               239.000000
# mean           9.021026          10.909204                 8.216736
# std           13.620161          10.353298                10.649538
# min            0.000000           0.000000                 0.000000
# 25%            2.750000           5.000000                 2.250000
# 50%            7.000000          10.000000                 6.000000
# 75%           10.000000          15.000000                10.000000
# max          100.000000         100.000000               100.000000
#
#        num_shocks_last_year  avg_shock_strength_last_year  phone_technology  \
# count          12600.000000                  12600.000000       12600.00000
# mean               1.100159                      2.112765           1.20873
# std                1.190072                      2.019239           1.09306
# min                0.000000                      0.000000           0.00000
# 25%                0.000000                      0.000000           0.00000
# 50%                1.000000                      2.000000           1.00000
# 75%                2.000000                      4.000000           2.00000
# max                5.000000                      5.000000           3.00000
#
#        phone_ownership  num_formal_institutions_last_year  \
# count     12600.000000                       12600.000000
# mean          1.468254                           0.714127
# std           0.776638                           0.805878
# min           0.000000                           0.000000
# 25%           1.000000                           0.000000
# 50%           2.000000                           1.000000
# 75%           2.000000                           1.000000
# max           2.000000                           6.000000
#
#        num_informal_institutions_last_year  num_financial_activities_last_year
# count                         12600.000000                        12600.000000
# mean                              0.188968                            1.559683
# std                               0.473696                            2.043831
# min                               0.000000                            0.000000
# 25%                               0.000000                            0.000000
# 50%                               0.000000                            1.000000
# 75%                               0.000000                            3.000000
# max                               4.000000                           10.000000

# %%
# Merge the poverty probability from train_data into the poverty_dataset
merged_data = poverty_data.merge(train_data, on='row_id', how='left')

# %%
merged_data.shape
# Out:
# (12600, 60)

# %%
# Distribution of the target variable (poverty_probability) in the train dataset
plt.figure(figsize=(8, 6))
sns.histplot(train_data['poverty_probability'], bins=30, kde=True)
plt.title("Distribution of Poverty Probability")
plt.xlabel("Poverty Probability")
plt.ylabel("Count")
plt.show()

# %%
# Correlation heatmap to visualize the relationships between numeric features
plt.figure(figsize=(12, 10))
sns.heatmap(merged_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Bar plot to visualize the count of urban and rural households in the poverty dataset
plt.figure(figsize=(6, 4))
sns.countplot(x='is_urban', data=merged_data)
plt.title("Count of Urban and Rural Households")
plt.xlabel("Urban/Rural")
plt.ylabel("Count")
plt.show()

# %%
# Bar plot to visualize the count of households by religion in the poverty dataset
plt.figure(figsize=(10, 6))
sns.countplot(x='religion', data=merged_data)
plt.title("Count of Households by Religion")
plt.xlabel("Religion")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Categorical feature bar plots
categorical_features = ['country', 'is_urban', 'married', 'religion', 'relationship_to_hh_head',
                        'education_level', 'literacy', 'employment_category_last_year', 'phone_technology']

for feature in categorical_features:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=merged_data, x=feature, order=poverty_data[feature].value_counts().index)
    plt.title(f"Bar Plot of {feature}")
    plt.xticks(rotation=45)
    plt.show()

# %%
# Numeric feature distributions
numeric_features = ['age', 'share_hh_income_provided', 'num_times_borrowed_last_year', 'avg_shock_strength_last_year',
                    'bank_interest_rate', 'mm_interest_rate', 'mfi_interest_rate', 'other_fsp_interest_rate']

for feature in numeric_features:
    plt.figure(figsize=(8, 6))
    sns.histplot(data=merged_data, x=feature, kde=True)
    plt.title(f"Distribution of {feature}")
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.show()

# %%
# Pairplot to visualize relationships between multiple numeric features
sns.pairplot(merged_data[numeric_features])
plt.title("Pairplot of Numeric Features")
plt.show()

# %%
# Interactive bar plot for poverty_probability by education_level using Plotly
fig = px.bar(merged_data, x='education_level', y='poverty_probability', color='is_urban', barmode='group',
             labels={'education_level': 'Education Level', 'poverty_probability': 'Poverty Probability'})
fig.update_layout(title='Poverty Probability by Education Level', xaxis_title='Education Level',
                  yaxis_title='Poverty Probability')
fig.show()

# %%
# Interactive scatter plot for age vs. poverty_probability using Plotly
fig = px.scatter(merged_data, x='age', y='poverty_probability', color='is_urban', hover_data=['country'],
                 labels={'age': 'Age', 'poverty_probability': 'Poverty Probability'})
fig.update_layout(title='Age vs. Poverty Probability', xaxis_title='Age', yaxis_title='Poverty Probability')
fig.show()

# %%
# Box plot for numeric features with respect to poverty_probability
for feature in numeric_features:
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=merged_data, x='poverty_probability', y=feature)
    plt.title(f"{feature} vs Poverty Probability")
    plt.xlabel("Poverty Probability")
    plt.ylabel(feature)
    plt.show()

# %% [markdown]
# ## Data Cleaning and Data Preprocessing

# %%
# Calculate the total number of missing values in each column
missing_values_count = merged_data.isnull().sum()

# Get the column names with missing values
columns_with_missing_values = missing_values_count[missing_values_count > 0].index

# Drop the columns with missing values from the DataFrame
merged_data_cleaned = merged_data.drop(columns=columns_with_missing_values)

# %%
merged_data_cleaned.shape
# Out:
# (12600, 54)

# %%
# Separate the target variable (poverty_probability) and features
X = merged_data_cleaned.drop(columns=['row_id', 'poverty_probability'])
y = merged_data_cleaned['poverty_probability']

# Split the data into train and test sets
# You can adjust the test_size and random_state parameters as needed
test_size = 0.2  # 20% of the data will be used for testing, change this as needed
random_state = 42  # Set a random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state)

# %%
train_columns_list = X_train.columns.tolist()
test_columns_list = X_test.columns.tolist()

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Loop through the specified columns and apply label encoding
for col in train_columns_list:
    X_train[col] = label_encoder.fit_transform(X_train[col])
for col in test_columns_list:
    X_test[col] = label_encoder.fit_transform(X_test[col])

# %%
# Use SelectKBest with f_regression score to select top 'k' features
k = 20  # Adjust this number as needed
selector = SelectKBest(score_func=f_regression, k=k)
X_train_new = selector.fit_transform(X_train, y_train)
X_test_new = selector.fit_transform(X_test, y_test)

# %%
print(X_train_new.shape)
print(y_train.shape)
# Out:
# (10080, 20)
# (10080,)

# %%
print(X_test_new.shape)
print(y_test.shape)
# Out:
# (2520, 20)
# (2520,)

# %% [markdown]
# ## Model Training and Evaluation

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train_new, y_train)
# Out:
# LinearRegression()

# %%
predictions = lr.predict(X_test_new)

# %%
predictions.shape
# Out:
# (2520,)

# %%
threshold = 0.5
binary_predictions = predictions >= threshold
accuracy = np.mean(binary_predictions == (y_test >= threshold)) * 100
print(f"Accuracy: {accuracy:.2f}%")

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"RMSE: {rmse:.2f}")
# Out:
# Accuracy: 72.18%
# RMSE: 0.27

# %%
# Define a threshold to convert probabilities to class labels (binary classification)
threshold = 0.5
binary_predictions = (predictions >= threshold).astype(int)
binary_true_labels = (y_test >= threshold).astype(int)

# Assuming you have the true labels for the test data
# true_labels = ...

# Generate the classification report
class_report = classification_report(binary_true_labels, binary_predictions)

print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.60      0.51      0.55       846
#            1       0.77      0.83      0.80      1674
#
#     accuracy                           0.72      2520
#    macro avg       0.69      0.67      0.67      2520
# weighted avg       0.71      0.72      0.72      2520

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x=predictions, y=y_test)
plt.xlabel('Predictions')
plt.ylabel('True Values')
plt.title('Scatter Plot: Predictions vs. True Values')

# Fit a linear regression line
regression_model = LinearRegression()
regression_model.fit(predictions.reshape(-1, 1), y_test)
plt.plot(predictions, regression_model.predict(predictions.reshape(-1, 1)), color='red', label='Linear Regression Line')

plt.legend()
plt.show()

# %%
joblib.dump(lr, 'LinearRegression.pkl')
# Out:
# ['LinearRegression.pkl']

# %% [markdown]
# ## K-Nearest Neighbour

# %%
knn = KNeighborsRegressor(n_neighbors=4)
knn.fit(X_train_new, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
y_pred = knn.predict(X_test_new)

# %%
threshold = 0.5
binary_predictions = (y_pred >= threshold).astype(int)
binary_true_labels = (y_test >= threshold).astype(int)
accuracy = np.mean(binary_predictions == (y_test >= threshold)) * 100
print(f"Accuracy: {accuracy:.2f}%")

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f"RMSE: {rmse:.2f}")
# Out:
# Accuracy: 68.13%
# RMSE: 0.29

# %%
class_report = classification_report(binary_true_labels, binary_predictions)

print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.53      0.50      0.51       846
#            1       0.75      0.77      0.76      1674
#
#     accuracy                           0.68      2520
#    macro avg       0.64      0.64      0.64      2520
# weighted avg       0.68      0.68      0.68      2520

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Scatter Plot: True Values vs. Predictions')

# Plot the KNN regression line
min_value = min(np.min(y_test), np.min(predictions))
max_value = max(np.max(y_test), np.max(predictions))
plt.plot([min_value, max_value], [min_value, max_value], color='red', label='KNN Regression Line')

plt.legend()
plt.show()

# %%
joblib.dump(knn, 'KNNRegression.pkl')
# Out:
# ['KNNRegression.pkl']

# %% [markdown]
# ## Random Forest

# %%
rf_regressor = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the Random Forest Regressor using the training data
rf_regressor.fit(X_train_new, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_predict = rf_regressor.predict(X_test_new)

# %%
threshold = 0.5
binary_predictions = (y_predict >= threshold).astype(int)
binary_true_labels = (y_test >= threshold).astype(int)
accuracy = np.mean(binary_predictions == (y_test >= threshold)) * 100
print(f"Accuracy: {accuracy:.2f}%")

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_test, y_predict))
print(f"RMSE: {rmse:.2f}")
# Out:
# Accuracy: 70.83%
# RMSE: 0.26

# %%
class_report = classification_report(binary_true_labels, binary_predictions)

print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.57      0.54      0.56       846
#            1       0.77      0.79      0.78      1674
#
#     accuracy                           0.71      2520
#    macro avg       0.67      0.67      0.67      2520
# weighted avg       0.71      0.71      0.71      2520

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_predict)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Scatter Plot: True Values vs. Predictions')

# Plot a random regression line (just for visualization)
min_value = min(np.min(y_test), np.min(predictions))
max_value = max(np.max(y_test), np.max(predictions))
random_slope = np.random.rand()  # Random slope between 0 and 1
random_intercept = np.random.rand()  # Random intercept between 0 and 1
plt.plot([min_value, max_value], [min_value * random_slope + random_intercept, max_value * random_slope + random_intercept], color='red', label='Random Regression Line')

plt.legend()
plt.show()

# %%
joblib.dump(rf_regressor, 'RandomForest.pkl')
# Out:
# ['RandomForest.pkl']

# %% [markdown]
# ## Support Vector Machine (SVM)

# %%
svm_regressor = SVR(kernel='rbf')

# Train the SVR model using the training data
svm_regressor.fit(X_train_new, y_train)
# Out:
# SVR()

# %%
y_pr = svm_regressor.predict(X_test_new)

# %%
threshold = 0.5
binary_predictions = (y_pr >= threshold).astype(int)
binary_true_labels = (y_test >= threshold).astype(int)
accuracy = np.mean(binary_predictions == (y_test >= threshold)) * 100
print(f"Accuracy: {accuracy:.2f}%")

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_test, y_pr))
print(f"RMSE: {rmse:.2f}")
# Out:
# Accuracy: 69.96%
# RMSE: 0.28

# %%
class_report = classification_report(binary_true_labels, binary_predictions)

print("Classification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.56      0.53      0.54       846
#            1       0.77      0.79      0.78      1674
#
#     accuracy                           0.70      2520
#    macro avg       0.66      0.66      0.66      2520
# weighted avg       0.70      0.70      0.70      2520

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pr)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('Scatter Plot: True Values vs. Predictions')

# Fit a linear regression line to the scatter plot
regression_model = LinearRegression()
regression_model.fit(y_test.values.reshape(-1, 1), predictions)
plt.plot(y_test, regression_model.predict(y_test.values.reshape(-1, 1)), color='red', label='Regression Line')

plt.legend()
plt.show()

# %%
joblib.dump(svm_regressor, 'SVM.pkl')
# Out:
# ['SVM.pkl']
